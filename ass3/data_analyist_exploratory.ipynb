# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import sys

# %%
df=pd.read_csv('train_set.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101923 entries, 0 to 101922
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   age             101923 non-null  int64
#  1   relaxation      101923 non-null  int64
#  2   Gtp             101923 non-null  int64
#  3   triglyceride    101923 non-null  int64
#  4   eyesight(left)  101923 non-null  float64
#  5   ALT             101923 non-null  int64
#  6   height(cm)      101923 non-null  int64
#  7   weight(kg)      101923 non-null  int64
#  8   waist(cm)       101923 non-null  float64
#  9   hearing(left)   101923 non-null  int64
#  10  smoking         101923 non-null  int64
# dtypes: float64(2), int64(9)
# memory usage: 8.6 MB

# %%
#EDA for all the features
df.describe().transpose()
# Out:
#                    count        mean        std    min    25%    50%    75%  \
# age             101923.0   44.322518  11.861661   20.0   40.0   40.0   55.0
# relaxation      101923.0   76.871010   8.985031   44.0   70.0   78.0   82.0
# Gtp             101923.0   36.325952  31.116333    3.0   18.0   27.0   44.0
# triglyceride    101923.0  128.027688  66.463590   11.0   77.0  115.0  166.0
# eyesight(left)  101923.0    1.006297   0.408518    0.1    0.8    1.0    1.2
# ALT             101923.0   26.560384  16.473788    1.0   16.0   22.0   32.0
# height(cm)      101923.0  165.264455   8.825500  135.0  160.0  165.0  170.0
# weight(kg)      101923.0   67.169795  12.594703   30.0   60.0   65.0   75.0
# waist(cm)       101923.0   83.024057   8.959248   51.0   77.0   83.0   89.0
# hearing(left)   101923.0    1.024106   0.153380    1.0    1.0    1.0    1.0
# smoking         101923.0    0.438331   0.496185    0.0    0.0    0.0    1.0
#
#                    max
# age               85.0
# relaxation       133.0
# Gtp              999.0
# triglyceride     548.0
# eyesight(left)     9.9
# ALT             1612.0
# height(cm)       190.0
# weight(kg)       130.0
# waist(cm)        127.0
# hearing(left)      2.0
# smoking            1.0

# %%
#EDA for continuous variables(EDA:Exploratory Data Analysis)
df[['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','relaxation','triglyceride','ALT','Gtp']].describe().transpose()
# Out:
#                    count        mean        std    min    25%    50%    75%  \
# age             101923.0   44.322518  11.861661   20.0   40.0   40.0   55.0
# height(cm)      101923.0  165.264455   8.825500  135.0  160.0  165.0  170.0
# weight(kg)      101923.0   67.169795  12.594703   30.0   60.0   65.0   75.0
# waist(cm)       101923.0   83.024057   8.959248   51.0   77.0   83.0   89.0
# eyesight(left)  101923.0    1.006297   0.408518    0.1    0.8    1.0    1.2
# relaxation      101923.0   76.871010   8.985031   44.0   70.0   78.0   82.0
# triglyceride    101923.0  128.027688  66.463590   11.0   77.0  115.0  166.0
# ALT             101923.0   26.560384  16.473788    1.0   16.0   22.0   32.0
# Gtp             101923.0   36.325952  31.116333    3.0   18.0   27.0   44.0
#
#                    max
# age               85.0
# height(cm)       190.0
# weight(kg)       130.0
# waist(cm)        127.0
# eyesight(left)     9.9
# relaxation       133.0
# triglyceride     548.0
# ALT             1612.0
# Gtp              999.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

continous_features = ['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','relaxation','triglyceride','ALT','Gtp']
fig, axes = plt.subplots(len(continous_features), 1, figsize=(10, 60))

for i, column in enumerate(continous_features):
    sns.histplot(data=df, x=column, kde=True, ax=axes[i])
plt.tight_layout()
plt.show()

# %%
#plot data for categorical features

#categ_feature=['hearing(left)']
sns.countplot(x='hearing(left)',data=df)
# Out:
# <Axes: xlabel='hearing(left)', ylabel='count'>

# %%
fig, ax=plt.subplots(1,1,figsize=(5,5))
def plot_pie(column):
    ax.pie(column.value_counts(),autopct='%1.2f%%',labels=column.value_counts().index)
    ax.legend(column.value_counts().index).set_title(column.name)
    ax.axis('equal')

plot_pie(df['smoking'])

# %%
#constract correlation matrix for continous features
corr=df[continous_features].corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b221a_row0_col0, #T_b221a_row1_col1, #T_b221a_row2_col2, #T_b221a_row3_col3, #T_b221a_row4_col4, #T_b221a_row5_col5, #T_b221a_row6_col6, #T_b221a_row7_col7, #T_b221a_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b221a_row0_col1, #T_b221a_row0_col2, #T_b221a_row0_col3, #T_b221a_row0_col4, #T_b221a_row0_col6, #T_b221a_row0_col7, #T_b221a_row0_col8, #T_b221a_row1_col0, #T_b221a_row4_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b221a_row0_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b221a_row1_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_b221a_row1_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_b221a_row1_col4, #T_b221a_row5_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_b221a_row1_col5 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b221a_row1_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b221a_row1_col7, #T_b221a_row6_col7, #T_b221a_row6_col8 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b221a_row1_col8, #T_b221a_row6_col4 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_b221a_row2_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b221a_row2_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_b221a_row2_col3 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_b221a_row2_col4, #T_b221a_row2_col8, #T_b221a_row3_col8, #T_b221a_row8_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b221a_row2_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b221a_row2_col6, #T_b221a_row5_col1 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_b221a_row2_col7, #T_b221a_row8_col1 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_b221a_row3_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b221a_row3_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_b221a_row3_col2 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_b221a_row3_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b221a_row3_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b221a_row3_col6 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_b221a_row3_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_b221a_row4_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b221a_row4_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_b221a_row4_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b221a_row4_col3, #T_b221a_row4_col8 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b221a_row4_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b221a_row4_col7, #T_b221a_row6_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_b221a_row5_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_b221a_row5_col3, #T_b221a_row8_col3 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b221a_row5_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b221a_row5_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_b221a_row5_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b221a_row5_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b221a_row6_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b221a_row6_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_b221a_row6_col2 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_b221a_row6_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b221a_row7_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b221a_row7_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_b221a_row7_col2 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_b221a_row7_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b221a_row7_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b221a_row7_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b221a_row7_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b221a_row7_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_b221a_row8_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_b221a_row8_col2, #T_b221a_row8_col7 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_b221a_row8_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b221a_row8_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b221a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b221a_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_b221a_level0_col1" class="col_heading level0 col1" >height(cm)</th>
#       <th id="T_b221a_level0_col2" class="col_heading level0 col2" >weight(kg)</th>
#       <th id="T_b221a_level0_col3" class="col_heading level0 col3" >waist(cm)</th>
#       <th id="T_b221a_level0_col4" class="col_heading level0 col4" >eyesight(left)</th>
#       <th id="T_b221a_level0_col5" class="col_heading level0 col5" >relaxation</th>
#       <th id="T_b221a_level0_col6" class="col_heading level0 col6" >triglyceride</th>
#       <th id="T_b221a_level0_col7" class="col_heading level0 col7" >ALT</th>
#       <th id="T_b221a_level0_col8" class="col_heading level0 col8" >Gtp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b221a_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_b221a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b221a_row0_col1" class="data row0 col1" >-0.488268</td>
#       <td id="T_b221a_row0_col2" class="data row0 col2" >-0.335632</td>
#       <td id="T_b221a_row0_col3" class="data row0 col3" >-0.041462</td>
#       <td id="T_b221a_row0_col4" class="data row0 col4" >-0.264507</td>
#       <td id="T_b221a_row0_col5" class="data row0 col5" >0.066263</td>
#       <td id="T_b221a_row0_col6" class="data row0 col6" >-0.039125</td>
#       <td id="T_b221a_row0_col7" class="data row0 col7" >-0.143002</td>
#       <td id="T_b221a_row0_col8" class="data row0 col8" >-0.048735</td>
#     </tr>
#     <tr>
#       <th id="T_b221a_level0_row1" class="row_heading level0 row1" >height(cm)</th>
#       <td id="T_b221a_row1_col0" class="data row1 col0" >-0.488268</td>
#       <td id="T_b221a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b221a_row1_col2" class="data row1 col2" >0.686052</td>
#       <td id="T_b221a_row1_col3" class="data row1 col3" >0.406893</td>
#       <td id="T_b221a_row1_col4" class="data row1 col4" >0.205653</td>
#       <td id="T_b221a_row1_col5" class="data row1 col5" >0.116223</td>
#       <td id="T_b221a_row1_col6" class="data row1 col6" >0.252591</td>
#       <td id="T_b221a_row1_col7" class="data row1 col7" >0.238198</td>
#       <td id="T_b221a_row1_col8" class="data row1 col8" >0.221239</td>
#     </tr>
#     <tr>
#       <th id="T_b221a_level0_row2" class="row_heading level0 row2" >weight(kg)</th>
#       <td id="T_b221a_row2_col0" class="data row2 col0" >-0.335632</td>
#       <td id="T_b221a_row2_col1" class="data row2 col1" >0.686052</td>
#       <td id="T_b221a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b221a_row2_col3" class="data row2 col3" >0.829606</td>
#       <td id="T_b221a_row2_col4" class="data row2 col4" >0.148134</td>
#       <td id="T_b221a_row2_col5" class="data row2 col5" >0.267314</td>
#       <td id="T_b221a_row2_col6" class="data row2 col6" >0.382203</td>
#       <td id="T_b221a_row2_col7" class="data row2 col7" >0.403083</td>
#       <td id="T_b221a_row2_col8" class="data row2 col8" >0.292970</td>
#     </tr>
#     <tr>
#       <th id="T_b221a_level0_row3" class="row_heading level0 row3" >waist(cm)</th>
#       <td id="T_b221a_row3_col0" class="data row3 col0" >-0.041462</td>
#       <td id="T_b221a_row3_col1" class="data row3 col1" >0.406893</td>
#       <td id="T_b221a_row3_col2" class="data row3 col2" >0.829606</td>
#       <td id="T_b221a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b221a_row3_col4" class="data row3 col4" >0.045068</td>
#       <td id="T_b221a_row3_col5" class="data row3 col5" >0.293104</td>
#       <td id="T_b221a_row3_col6" class="data row3 col6" >0.390743</td>
#       <td id="T_b221a_row3_col7" class="data row3 col7" >0.383039</td>

# %%
df.groupby(by="smoking").agg('mean')[['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','relaxation','triglyceride','ALT','Gtp']].plot(kind='bar',figsize=(20,10))
# Out:
# <Axes: xlabel='smoking'>

# %%
df.groupby(by="smoking").agg('mean')[['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','relaxation','triglyceride','ALT','Gtp']]
# Out:
#                age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# smoking
# 0        46.482750  161.773962   63.258249  80.952956        0.970709
# 1        41.554436  169.737107   72.181977  85.677928        1.051898
#
#          relaxation  triglyceride        ALT        Gtp
# smoking
# 0         75.969885    108.589149  23.983405  27.806645
# 1         78.025696    152.935872  29.862476  47.242434

# %%
#plot KDE for continous features (KDE: Kernel Density Estimation, it is used for visualizing the Probability Density of a continuous variable)
fig, axes = plt.subplots(len(continous_features), 1, figsize=(10, 60))
for i, column in enumerate(continous_features):
    sns.kdeplot(data=df, x=column,hue='smoking',fill=True, ax=axes[i])

# %%
sns.countplot(x='hearing(left)',hue='smoking',data=df)
# Out:
# <Axes: xlabel='hearing(left)', ylabel='count'>

# %%
#plot the multivalued analysis for continous features
sns.pairplot(data=df[['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','relaxation','triglyceride','ALT','Gtp','smoking']],hue='smoking')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#scalling the features for feature engineering
import sklearn.preprocessing as preprocessing
scaler = preprocessing.StandardScaler().fit(df[['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','relaxation','triglyceride','ALT','Gtp']])
X_scaled = scaler.transform(df[['age','height(cm)','weight(kg)','waist(cm)','eyesight(left)','relaxation','triglyceride','ALT','Gtp']])
X_scaled.mean(axis=0)
# Out:
# array([ 2.07746765e-17,  2.78854718e-19,  6.06509012e-18,  4.18282077e-19,
#        -4.11310709e-18,  1.54415800e-17,  1.53370095e-18, -3.22077199e-17,
#         1.55984358e-18])
